# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd

df = pd.read_csv('Resources/client_dataset.csv')
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# View the column names in the data
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
df.describe()
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number
# count  54639.000000  54639.000000  5.463900e+04  54639.000000
# mean      99.446073      5.004116  5.702646e+02      2.979667
# std      133.164267      5.326599  1.879552e+04      2.436320
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
df.info()
non_null_counts = df.count()
print(non_null_counts)
# add profit column
df['profit'] = df['unit_price'] - df['unit_cost']
# add profit % column
df['profit_margin (%)'] = ((df['unit_price'] - df['unit_cost']) / df['unit_price']) * 100
# sort client by highest weekly order, then highest yearly order
profit_sorted_df = df.sort_values(by=['profit_margin (%)', 'order_year', 'order_week'], ascending=False)
profit_sorted_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54639 entries, 0 to 54638
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   first        54639 non-null  object
#  1   last         54639 non-null  object
#  2   job          54639 non-null  object
#  3   phone        54639 non-null  object
#  4   email        54639 non-null  object
#  5   client_id    54639 non-null  int64
#  6   order_id     54639 non-null  int64
#  7   order_date   54639 non-null  object
#  8   order_week   54639 non-null  int64
#  9   order_year   54639 non-null  int64
#  10  item_id      54639 non-null  object
#  11  category     54639 non-null  object
#  12  subcategory  54639 non-null  object
#  13  unit_price   54639 non-null  float64
#  14  unit_cost    54639 non-null  float64
#  15  unit_weight  54639 non-null  float64
#  16  qty          54639 non-null  int64
#  17  line_number  54639 non-null  int64
# ...

# %%
# What three item categories had the most entries?
category_counts = df['category'].value_counts()
category_counts.head(3)
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
# For the category with the most entries, which subcategory had the most entries?
filtered_df = df[df['category'] == 'consumables']
subcategory_counts = df['subcategory'].value_counts()
subcategory_counts.head()
# Out:
# subcategory
# bathroom supplies    6424
# paper products       5874
# kitchen supplies     5746
# tables               4540
# misc                 4286
# Name: count, dtype: int64

# %%
# Which five clients had the most entries in the data?
top5entries_client_counts = df['client_id'].value_counts()
top5entries_client_counts.head(5)
clients_df = pd.merge(df, top5entries_client_counts.head(5), on=["client_id"])
unique_records = clients_df.drop_duplicates(subset=['first', 'last'])
unique_records.head()
# Out:
#        first     last                                           job  \
# 0    Jessica    Reyes  Production designer, theatre/television/film
# 2      Bryan    Myers                                Chief of Staff
# 4     Angela  Everett                                     Osteopath
# 6     Kendra  Garrett                        Pension scheme manager
# 8  Alexandra    Young                                     Dietitian
#
#               phone                            email  client_id  order_id  \
# 0        5016915923         jessica.reyes@grimes.net      33615   1327730
# 2  444.233.9146x233            bmyers3696@wilson.com      46820   7109502
# 4  729-620-6192x875           aeverett@rodriguez.com      66037   1203693
# 6      808.257.2029  garrettkendra8479@jefferson.com      24741   3699423
# 8  265-666-3155x118           ayoung9158@stevens.com      38378   8539164
#
#    order_date  order_week  order_year  ...     category        subcategory  \
# ...

# %%
# Store the client ids of those top 5 clients in a list.
top5entries_client_list = unique_records['client_id'].tolist()
print(top5entries_client_list)
# Out:
# [33615, 46820, 66037, 24741, 38378]

# %%
# How many total units (the qty column) did the client with the most entries order order?
top5entries_client_df = df.query('client_id == 33615')
print(top5entries_client_df['qty'].sum())
# Out:
# 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the subtotal for each line using the unit_price and the qty
df['subtotal'] = df['unit_price'] * df['qty']
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ...     category         subcategory unit_price  \
# ...

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound for orders over 50 pounds and $10 per pound for items 50 pounds or under.
df['order_weight'] = df['unit_weight'] * df['qty']
df['shipping_price'] = df['order_weight'].apply(
    lambda x: 7 * x if x > 50 else 10 * x)
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ... unit_price unit_cost unit_weight  qty  \
# ...

# %%
# Create a column for the total price using the subtotal and the shipping price along with a sales tax of 9.25%
df['total_price'] = 1.0925 * (df['subtotal'] + df['shipping_price'])
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ... unit_cost unit_weight  qty  line_number  \
# ...

# %%
# Create a column for the cost of each line using unit cost, qty, and
# shipping price (assume the shipping cost is exactly what is charged to the client).
df["total_line_cost"] = df["unit_cost"] * df["qty"]+ df["shipping_price"]
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ... unit_weight  qty line_number  profit  \
# ...

# %%
# Create a column for the profit of each line using line cost and line price
df["total_line_profit"] = df["total_price"] - df["total_line_cost"]
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ...  qty line_number  profit  profit_margin (%)  \
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above
#print(f'{order_id} {order_total}')

order_2742071_df = df.query('order_id == 2742071')
print(f"Order: 2742071 Total: ${order_2742071_df['total_price'].sum() :,.2f}")

order_2173913_df = df.query('order_id == 2173913')
print(f"Order: 2173913 Total: ${order_2173913_df['total_price'].sum() :,.2f}")

order_6128929_df = df.query('order_id == 6128929')
print(f"Order: 6128929 Total: ${order_6128929_df['total_price'].sum() :,.2f}")
# Out:
# Order: 2742071 Total: $152,811.90
# Order: 2173913 Total: $162,388.72
# Order: 6128929 Total: $923,441.24

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity spend? Check your work from Part 1 for client ids.
order_33615_df = df.query('client_id == 33615')
print(f"Order: 33615 Total: ${order_33615_df['total_price'].sum() :,.2f}")

order_66037_df = df.query('client_id == 66037')
print(f"Order: 66037 Total: ${order_66037_df['total_price'].sum() :,.2f}")

order_46820_df = df.query('client_id == 46820')
print(f"Order: 46820 Total: ${order_46820_df['total_price'].sum() :,.2f}")

order_38378_df = df.query('client_id == 38378')
print(f"Order: 38378 Total: ${order_38378_df['total_price'].sum() :,.2f}")

order_24741_df = df.query('client_id == 24741')
print(f"Order: 24741 Total: ${order_24741_df['total_price'].sum() :,.2f}")
# Out:
# Order: 33615 Total: $8,377,308.57
# Order: 66037 Total: $10,259,514.80
# Order: 46820 Total: $9,743,794.32
# Order: 38378 Total: $12,906,550.88
# Order: 24741 Total: $82,268,891.98

# %%
# Create a summary DataFrame showing the totals for the for the top 5 clients with the following information:
# total units purchased, total shipping price, total revenue, and total profit. 

client_summary = df.groupby('client_id').agg(
    total_units_purchased=('qty', 'sum'),
    total_shipping_price=('unit_weight', 'sum'), 
    total_revenue=('total_price', 'sum'),
    total_profit=('total_line_profit', 'sum')
)

top5_client_summary = client_summary.query('client_id.isin(@top5entries_client_list)').copy()

top5_client_summary
# Out:
#            total_units_purchased  total_shipping_price  total_revenue  \
# client_id
# 24741                     239862                936.56   8.226889e+07
# 33615                      64313               1260.94   8.377309e+06
# 38378                      73667               1189.50   1.290655e+07
# 46820                      75768               1109.48   9.743794e+06
# 66037                      43018               1001.73   1.025951e+07
#
#            total_profit
# client_id
# 24741      3.657999e+07
# 33615      2.201995e+06
# 38378      3.271830e+06
# 46820      2.736603e+06
# 66037      3.255032e+06

# %%
# Format the data and rename the columns to names suitable for presentation.
top5_client_summary.columns = ['Total Units Purchased', 
                               'Total Shipping', 
                               'Total Revenue', 
                               'Total Profit']

# Define the money columns. 
money_columns = ['Total Revenue', 
                 'Total Profit']

# Define a function that converts a dollar amount to millions.
def currency_format_millions(x):
    return '{:,.2f}'.format(int(x) / 1e6)

# Apply the currency_format_millions function to only the money columns. 
top5_client_summary[money_columns] = top5_client_summary[money_columns].map(currency_format_millions)
top5_client_summary['Total Units Purchased'] = top5_client_summary['Total Units Purchased'].map(lambda x: f'{x:,}')
 
# Rename the columns to reflect the change in the money format. 
top5_client_summary.rename(columns={
    'Total Revenue': 'Total Revenue (Millions)',
    'Total Profit': 'Total Profit (Millions)',
}, inplace=True)

top5_client_summary.index = top5_client_summary.index.rename('Client ID')

top5_client_summary
# Out:
#           Total Units Purchased  Total Shipping Total Revenue (Millions)  \
# Client ID
# 24741                   239,862          936.56                    82.27
# 33615                    64,313         1260.94                     8.38
# 38378                    73,667         1189.50                    12.91
# 46820                    75,768         1109.48                     9.74
# 66037                    43,018         1001.73                    10.26
#
#           Total Profit (Millions)
# Client ID
# 24741                       36.58
# 33615                        2.20
# 38378                        3.27
# 46820                        2.74
# 66037                        3.26

# %%
# Sort the updated data by "Total Profit (millions)" form highest to lowest and assign the sort to a new DatFrame.
top5_client_summary_sorted = top5_client_summary.sort_values(
    by=['Total Profit (Millions)'], ascending=False)
top5_client_summary_sorted
# Out:
#           Total Units Purchased  Total Shipping Total Revenue (Millions)  \
# Client ID
# 24741                   239,862          936.56                    82.27
# 38378                    73,667         1189.50                    12.91
# 66037                    43,018         1001.73                    10.26
# 46820                    75,768         1109.48                     9.74
# 33615                    64,313         1260.94                     8.38
#
#           Total Profit (Millions)
# Client ID
# 24741                       36.58
# 38378                        3.27
# 66037                        3.26
# 46820                        2.74
# 33615                        2.20
